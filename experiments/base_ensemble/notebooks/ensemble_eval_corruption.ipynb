# %% [markdown]
# # Corrupted Data Evaluation
# Systematische Evaluation des Ensembles über verschiedene Corruption-Typen und Severity-Level

# %% [markdown]
# ## Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Clone repository
# !git clone -b feat/single-eval --single-branch https://github.com/deadPixelsGreta/xAI-proj-m-ws2526.git
# Out:
# Cloning into 'xAI-proj-m-ws2526'...
# remote: Enumerating objects: 1155, done.
# remote: Counting objects: 100% (244/244), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 1155 (delta 204), reused 181 (delta 168), pack-reused 911 (from 1)
# Receiving objects: 100% (1155/1155), 140.54 MiB | 17.17 MiB/s, done.
# Resolving deltas: 100% (612/612), done.

# %%
# Setup project root
import sys, os
from pathlib import Path

def find_project_root(start: Path) -> Path:
    markers = {".git", "requirements.txt", "setup.py", "pyproject.toml"}
    root = None
    for parent in [start, *start.parents]:
        if any((parent / m).exists() for m in markers):
            root = parent
    return root or start

cloned_repo_name = "xAI-proj-m-ws2526"
cloned_repo_path = Path.cwd() / cloned_repo_name

if cloned_repo_path.is_dir():
    os.chdir(cloned_repo_path)

ROOT = find_project_root(Path.cwd()).resolve()
os.chdir(ROOT)

if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

print("cwd:", Path.cwd())
print("root on sys.path:", str(ROOT) in sys.path)
# Out:
# cwd: /content/xAI-proj-m-ws2526
# root on sys.path: True

# %%
# Install dependencies
# !pip install -r experiments/base_ensemble/requirements.txt --quiet

# %% [markdown]
# ## Load Corrupted Dataset

# %%
# 1. Copy zip from Drive to local VM
# !cp /content/drive/MyDrive/corrupted.zip /content/

# 2. Unzip directly to /content/
# !unzip -q /content/corrupted.zip -d /content/

# 3. Move to datasets folder
# !mv /content/corrupted/ /content/xAI-proj-m-ws2526/datasets/

# 4. Remove the zip to save space
# !rm /content/corrupted.zip

# %% [markdown]
# ## Systematische Evaluation über alle Corruption-Typen und Levels

# %%
import subprocess
import re
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import shutil

# Checkpoints
CHECKPOINT_DIR = "/content/drive/MyDrive/best_models_resnet"
CHECKPOINT = [
    "best_resnet50-20260130-181509_epoch8.pth",
    "best_resnet18-20260107-144624_epoch15.pth",
    "copy-best_resnet34_color_seed42.pth"
]
# Corruption
corruption_types = ['gaussian_noise', 'pixelate']

# Severity levels
severity_levels = [1, 2, 3, 4, 5]

# Results storage
results = []

print("="*80)
print("Starting Systematic Corruption Evaluation")
print("="*80)

for corruption in corruption_types:
    print(f"\n{'='*80}")
    print(f"Corruption Type: {corruption.upper()}")
    print("="*80)

    for severity in severity_levels:
        print(f"\n{'-'*80}")
        print(f"Evaluating: {corruption} - Severity Level {severity}")
        print("-"*80)

        # Path to severity level
        data_dir = f"datasets/test/{corruption}/severity_{severity}"

        # Check if path exists
        if not Path(data_dir).exists():
            print(f"Skipping: {data_dir} does not exist")
            continue

        # Run evaluation
        cmd = [
            "python", "-m", "experiments.base_ensemble.scripts.ensemble_inference",
            "--evaluate",
            "--data-dir", data_dir,
            "--split", "",
            "--checkpoints", f"{CHECKPOINT_DIR}/{CHECKPOINT}"
        ]
        # alle Checkpoint-Pfade
        cmd.extend([f"{CHECKPOINT_DIR}/{ckpt}" for ckpt in CHECKPOINTS])

        try:
            result = subprocess.run(cmd, capture_output=True, text=True, check=True)
            output = result.stdout

            # Overall Accuracy
            accuracy_match = re.search(r'Overall Ensemble Accuracy:\s*(\d+\.\d+)%', output)
            if accuracy_match:
                accuracy = float(accuracy_match.group(1))
                results.append({
                    'Corruption': corruption,
                    'Severity': severity,
                    'Accuracy': accuracy
                })
                print(f"Overall Ensemble Accuracy {CHECKPOINT}: {accuracy:.2f}%")

            # Print results
            print("\n" + output)

        except subprocess.CalledProcessError as e:
            print(f"Error: {e}")
            print(e.stderr)

print("\n" + "="*80)
print("Evaluation Check")
print("="*80)

df = pd.DataFrame(results)

if not df.empty:
    # Pivot-Table
    pivot_df = df.pivot(index='Severity', columns='Corruption', values='Accuracy')

    print("\n" + "="*80)
    print(f"Final: Accuracy across Corruption Types and Severity Levels for {CHECKPOINT}")
    print("="*80)
    print(pivot_df.to_string())

    # CSV
    df.to_csv(f'{CHECKPOINT}_ensemble_3res_corruption_evaluation_results.csv', index=False)
    print(f"\nSave: {CHECKPOINT}_ensemble_3res_corruption_evaluation_results.csv")

    # Plot
    plt.figure(figsize=(12, 6))
    for corruption in df['Corruption'].unique():
        subset = df[df['Corruption'] == corruption]
        plt.plot(subset['Severity'], subset['Accuracy'], marker='o', label=corruption)

    plt.xlabel('Severity Level')
    plt.ylabel('Accuracy (%)')
    plt.title('3 Models Resnets Aug Robustness across Corruption Types')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.xticks([1, 2, 3, 4, 5])
    plt.savefig(f'{CHECKPOINT}_ensemble_3res_corruption_evaluation_plot.png', dpi=300, bbox_inches='tight')
    plt.show()

    print(f"Generate: {CHECKPOINT}_ensemble_3res_corruption_evaluation_plot.png")

    # Google Drive
    shutil.copy(f'{CHECKPOINT}_ensemble_3res_corruption_evaluation_results.csv', '/content/drive/MyDrive/')
    shutil.copy(f'{CHECKPOINT}_ensemble_3res_corruption_evaluation_plot.png', '/content/drive/MyDrive/')
    print("All saved to Google Drive")

else:
    print("No results to display.")
    print(f"Results list length: {len(results)}")
# Out:
# ================================================================================
# Starting Systematic Corruption Evaluation
# ================================================================================
#
# ================================================================================
# Corruption Type: GAUSSIAN_NOISE
# ================================================================================
#
# --------------------------------------------------------------------------------
# Evaluating: gaussian_noise - Severity Level 1
# --------------------------------------------------------------------------------
# Overall Accuracy best_vit_b_16.pth: 85.80%
#
# ============================================================
# Ensemble Inference for ImageNetSubset
# ============================================================
#
# Device: CUDA (Tesla T4)
#
#  Loading 1 model(s):
#    ✓ vit_b_16             (val acc: 91.6%) from best_vit_b_16.pth
#
# ============================================================
#  Ensemble Evaluation on Direct Set
# ============================================================
#
#  Per-Class Accuracy Comparison:
#    Class                | Ensemble | vit_b_16
# -------------------------------------------------
#    binder               |    90.0% |        90.0% |
#    coffee_mug           |    80.0% |        80.0% |
#    computer_keyboard    |    84.0% |        84.0% |
#    mouse                |    60.0% |        60.0% |
#    notebook             |    74.0% |        74.0% |
#    remote_control       |    98.0% |        98.0% |
#    soup_bowl            |    94.0% |        94.0% |
#    teapot               |   100.0% |       100.0% |
#    toilet_tissue        |    90.0% |        90.0% |
#    wooden_spoon         |    88.0% |        88.0% |
# -------------------------------------------------
#
#  Performance Metrics:
# --------------------------------------------------
#    Overall Ensemble Accuracy: 85.80%
#    Oracle Accuracy:           85.80% (theoretical max)
#    Expected Calibration Error: 0.1843
#    Average Disagreement:        nan
#    Average Agreement Ratio:   100.0%
#    Total Images:              500
#
#  Model Comparison (Overall):
# --------------------------------------------------
#    vit_b_16                  85.80%
#    ENSEMBLE                  85.80% *
#
# ============================================================
# Inference Complete!
# ============================================================
#
#
# --------------------------------------------------------------------------------
# Evaluating: gaussian_noise - Severity Level 2
# --------------------------------------------------------------------------------
# Overall Accuracy best_vit_b_16.pth: 81.80%
#
# ============================================================
# Ensemble Inference for ImageNetSubset
# ============================================================
#
# Device: CUDA (Tesla T4)
#
#  Loading 1 model(s):
#    ✓ vit_b_16             (val acc: 91.6%) from best_vit_b_16.pth
#
# ============================================================
#  Ensemble Evaluation on Direct Set
# ============================================================
#
#  Per-Class Accuracy Comparison:
#    Class                | Ensemble | vit_b_16
# -------------------------------------------------
#    binder               |    84.0% |        84.0% |
#    coffee_mug           |    72.0% |        72.0% |
#    computer_keyboard    |    82.0% |        82.0% |
#    mouse                |    50.0% |        50.0% |
#    notebook             |    70.0% |        70.0% |
#    remote_control       |    94.0% |        94.0% |
#    soup_bowl            |    96.0% |        96.0% |
#    teapot               |    96.0% |        96.0% |
#    toilet_tissue        |    86.0% |        86.0% |
#    wooden_spoon         |    88.0% |        88.0% |
# -------------------------------------------------
#
#  Performance Metrics:
# --------------------------------------------------
#    Overall Ensemble Accuracy: 81.80%
#    Oracle Accuracy:           81.80% (theoretical max)
#    Expected Calibration Error: 0.1652
#    Average Disagreement:        nan
#    Average Agreement Ratio:   100.0%
#    Total Images:              500
#
#  Model Comparison (Overall):
# --------------------------------------------------
#    vit_b_16                  81.80%
#    ENSEMBLE                  81.80% *
#
# ============================================================
# Inference Complete!
# ============================================================
#
#
# --------------------------------------------------------------------------------
# Evaluating: gaussian_noise - Severity Level 3
# --------------------------------------------------------------------------------
# Overall Accuracy best_vit_b_16.pth: 80.40%
#
# ============================================================
# Ensemble Inference for ImageNetSubset
# ============================================================
#
# Device: CUDA (Tesla T4)
#
#  Loading 1 model(s):
#    ✓ vit_b_16             (val acc: 91.6%) from best_vit_b_16.pth
#
# ============================================================
#  Ensemble Evaluation on Direct Set
# ============================================================
#
#  Per-Class Accuracy Comparison:
#    Class                | Ensemble | vit_b_16
# -------------------------------------------------
#    binder               |    88.0% |        88.0% |
#    coffee_mug           |    70.0% |        70.0% |
#    computer_keyboard    |    82.0% |        82.0% |
#    mouse                |    38.0% |        38.0% |
#    notebook             |    74.0% |        74.0% |
#    remote_control       |    88.0% |        88.0% |
#    soup_bowl            |    96.0% |        96.0% |
#    teapot               |    92.0% |        92.0% |
#    toilet_tissue        |    86.0% |        86.0% |
#    wooden_spoon         |    90.0% |        90.0% |
# -------------------------------------------------
#
#  Performance Metrics:
# --------------------------------------------------
#    Overall Ensemble Accuracy: 80.40%
#    Oracle Accuracy:           80.40% (theoretical max)
#    Expected Calibration Error: 0.1922
#    Average Disagreement:        nan
#    Average Agreement Ratio:   100.0%
#    Total Images:              500
#
#  Model Comparison (Overall):
# --------------------------------------------------
#    vit_b_16                  80.40%
#    ENSEMBLE                  80.40% *
#
# ============================================================
# Inference Complete!
# ============================================================
#
#
# --------------------------------------------------------------------------------
# Evaluating: gaussian_noise - Severity Level 4
# --------------------------------------------------------------------------------
# Overall Accuracy best_vit_b_16.pth: 73.00%
#
# ============================================================
# Ensemble Inference for ImageNetSubset
# ============================================================
#
# Device: CUDA (Tesla T4)
#
#  Loading 1 model(s):
#    ✓ vit_b_16             (val acc: 91.6%) from best_vit_b_16.pth
#
# ============================================================
#  Ensemble Evaluation on Direct Set
# ============================================================
#
#  Per-Class Accuracy Comparison:
#    Class                | Ensemble | vit_b_16
# -------------------------------------------------
#    binder               |    80.0% |        80.0% |
#    coffee_mug           |    54.0% |        54.0% |
#    computer_keyboard    |    78.0% |        78.0% |
#    mouse                |    40.0% |        40.0% |
#    notebook             |    60.0% |        60.0% |
#    remote_control       |    88.0% |        88.0% |
#    soup_bowl            |    92.0% |        92.0% |
#    teapot               |    92.0% |        92.0% |
#    toilet_tissue        |    66.0% |        66.0% |
#    wooden_spoon         |    80.0% |        80.0% |
# -------------------------------------------------
#
#  Performance Metrics:
# --------------------------------------------------
#    Overall Ensemble Accuracy: 73.00%
#    Oracle Accuracy:           73.00% (theoretical max)
#    Expected Calibration Error: 0.1905
#    Average Disagreement:        nan
#    Average Agreement Ratio:   100.0%
#    Total Images:              500
#
#  Model Comparison (Overall):
# --------------------------------------------------
#    vit_b_16                  73.00%
#    ENSEMBLE                  73.00% *
#
# ============================================================
# Inference Complete!
# ============================================================
#
#
# --------------------------------------------------------------------------------
# Evaluating: gaussian_noise - Severity Level 5
# --------------------------------------------------------------------------------
# Overall Accuracy best_vit_b_16.pth: 64.20%
#
# ============================================================
# Ensemble Inference for ImageNetSubset
# ============================================================
#
# Device: CUDA (Tesla T4)
#
#  Loading 1 model(s):
#    ✓ vit_b_16             (val acc: 91.6%) from best_vit_b_16.pth
#
# ============================================================
#  Ensemble Evaluation on Direct Set
# ============================================================
#
#  Per-Class Accuracy Comparison:
#    Class                | Ensemble | vit_b_16
# -------------------------------------------------
#    binder               |    68.0% |        68.0% |
#    coffee_mug           |    44.0% |        44.0% |
#    computer_keyboard    |    72.0% |        72.0% |
#    mouse                |    16.0% |        16.0% |
#    notebook             |    66.0% |        66.0% |
#    remote_control       |    82.0% |        82.0% |
#    soup_bowl            |    86.0% |        86.0% |
#    teapot               |    78.0% |        78.0% |
#    toilet_tissue        |    54.0% |        54.0% |
#    wooden_spoon         |    76.0% |        76.0% |
# -------------------------------------------------
#
#  Performance Metrics:
# --------------------------------------------------
#    Overall Ensemble Accuracy: 64.20%
#    Oracle Accuracy:           64.20% (theoretical max)
#    Expected Calibration Error: 0.2063
#    Average Disagreement:        nan
#    Average Agreement Ratio:   100.0%
#    Total Images:              500
#
#  Model Comparison (Overall):
# --------------------------------------------------
#    vit_b_16                  64.20%
#    ENSEMBLE                  64.20% *
#
# ============================================================
# Inference Complete!
# ============================================================
#
#
# ================================================================================
# Corruption Type: PIXELATE
# ================================================================================
#
# --------------------------------------------------------------------------------
# Evaluating: pixelate - Severity Level 1
# --------------------------------------------------------------------------------
# Overall Accuracy best_vit_b_16.pth: 87.60%
#
# ============================================================
# Ensemble Inference for ImageNetSubset
# ============================================================
#
# Device: CUDA (Tesla T4)
#
#  Loading 1 model(s):
#    ✓ vit_b_16             (val acc: 91.6%) from best_vit_b_16.pth
#
# ============================================================
#  Ensemble Evaluation on Direct Set
# ============================================================
#
#  Per-Class Accuracy Comparison:
#    Class                | Ensemble | vit_b_16
# -------------------------------------------------
#    binder               |    98.0% |        98.0% |
#    coffee_mug           |    82.0% |        82.0% |
#    computer_keyboard    |    92.0% |        92.0% |
#    mouse                |    74.0% |        74.0% |
#    notebook             |    70.0% |        70.0% |
#    remote_control       |    94.0% |        94.0% |
#    soup_bowl            |    92.0% |        92.0% |
#    teapot               |   100.0% |       100.0% |
#    toilet_tissue        |    88.0% |        88.0% |
#    wooden_spoon         |    86.0% |        86.0% |
# -------------------------------------------------
#
#  Performance Metrics:
# --------------------------------------------------
#    Overall Ensemble Accuracy: 87.60%
#    Oracle Accuracy:           87.60% (theoretical max)
#    Expected Calibration Error: 0.1764
#    Average Disagreement:        nan
#    Average Agreement Ratio:   100.0%
#    Total Images:              500
#
#  Model Comparison (Overall):
# --------------------------------------------------
#    vit_b_16                  87.60%
#    ENSEMBLE                  87.60% *
#
# ============================================================
# Inference Complete!
# ============================================================
#
#
# --------------------------------------------------------------------------------
# Evaluating: pixelate - Severity Level 2
# --------------------------------------------------------------------------------
# Overall Accuracy best_vit_b_16.pth: 86.40%
#
# ============================================================
# Ensemble Inference for ImageNetSubset
# ============================================================
#
# Device: CUDA (Tesla T4)
#
#  Loading 1 model(s):
#    ✓ vit_b_16             (val acc: 91.6%) from best_vit_b_16.pth
#
# ============================================================
#  Ensemble Evaluation on Direct Set
# ============================================================
#
#  Per-Class Accuracy Comparison:
#    Class                | Ensemble | vit_b_16
# -------------------------------------------------
#    binder               |    94.0% |        94.0% |
#    coffee_mug           |    80.0% |        80.0% |
#    computer_keyboard    |    86.0% |        86.0% |
#    mouse                |    74.0% |        74.0% |
#    notebook             |    68.0% |        68.0% |
#    remote_control       |    94.0% |        94.0% |
#    soup_bowl            |    92.0% |        92.0% |
#    teapot               |   100.0% |       100.0% |
#    toilet_tissue        |    88.0% |        88.0% |
#    wooden_spoon         |    88.0% |        88.0% |
# -------------------------------------------------
#
#  Performance Metrics:
# --------------------------------------------------
#    Overall Ensemble Accuracy: 86.40%
#    Oracle Accuracy:           86.40% (theoretical max)
#    Expected Calibration Error: 0.1785
#    Average Disagreement:        nan
#    Average Agreement Ratio:   100.0%
#    Total Images:              500
#
#  Model Comparison (Overall):
# --------------------------------------------------
#    vit_b_16                  86.40%
#    ENSEMBLE                  86.40% *
#
# ============================================================
# Inference Complete!
# ============================================================
#
#
# --------------------------------------------------------------------------------
# Evaluating: pixelate - Severity Level 3
# --------------------------------------------------------------------------------
# Overall Accuracy best_vit_b_16.pth: 84.00%
#
# ============================================================
# Ensemble Inference for ImageNetSubset
# ============================================================
#
# Device: CUDA (Tesla T4)
#
#  Loading 1 model(s):
#    ✓ vit_b_16             (val acc: 91.6%) from best_vit_b_16.pth
#
# ============================================================
#  Ensemble Evaluation on Direct Set
# ============================================================
#
#  Per-Class Accuracy Comparison:
#    Class                | Ensemble | vit_b_16
# -------------------------------------------------
#    binder               |    96.0% |        96.0% |
#    coffee_mug           |    80.0% |        80.0% |
#    computer_keyboard    |    86.0% |        86.0% |
#    mouse                |    58.0% |        58.0% |
#    notebook             |    70.0% |        70.0% |
#    remote_control       |    90.0% |        90.0% |
#    soup_bowl            |    96.0% |        96.0% |
#    teapot               |    98.0% |        98.0% |
#    toilet_tissue        |    82.0% |        82.0% |
#    wooden_spoon         |    84.0% |        84.0% |
# -------------------------------------------------
#
#  Performance Metrics:
# --------------------------------------------------
#    Overall Ensemble Accuracy: 84.00%
#    Oracle Accuracy:           84.00% (theoretical max)
#    Expected Calibration Error: 0.1899
#    Average Disagreement:        nan
#    Average Agreement Ratio:   100.0%
#    Total Images:              500
#
#  Model Comparison (Overall):
# --------------------------------------------------
#    vit_b_16                  84.00%
#    ENSEMBLE                  84.00% *
#
# ============================================================
# Inference Complete!
# ============================================================
#
#
# --------------------------------------------------------------------------------
# Evaluating: pixelate - Severity Level 4
# --------------------------------------------------------------------------------
# Overall Accuracy best_vit_b_16.pth: 78.00%
#
# ============================================================
# Ensemble Inference for ImageNetSubset
# ============================================================
#
# Device: CUDA (Tesla T4)
#
#  Loading 1 model(s):
#    ✓ vit_b_16             (val acc: 91.6%) from best_vit_b_16.pth
#
# ============================================================
#  Ensemble Evaluation on Direct Set
# ============================================================
#
#  Per-Class Accuracy Comparison:
#    Class                | Ensemble | vit_b_16
# -------------------------------------------------
#    binder               |    94.0% |        94.0% |
#    coffee_mug           |    76.0% |        76.0% |
#    computer_keyboard    |    86.0% |        86.0% |
#    mouse                |    40.0% |        40.0% |
#    notebook             |    58.0% |        58.0% |
#    remote_control       |    82.0% |        82.0% |
#    soup_bowl            |    96.0% |        96.0% |
#    teapot               |    96.0% |        96.0% |
#    toilet_tissue        |    76.0% |        76.0% |
#    wooden_spoon         |    76.0% |        76.0% |
# -------------------------------------------------
#
#  Performance Metrics:
# --------------------------------------------------
#    Overall Ensemble Accuracy: 78.00%
#    Oracle Accuracy:           78.00% (theoretical max)
#    Expected Calibration Error: 0.1861
#    Average Disagreement:        nan
#    Average Agreement Ratio:   100.0%
#    Total Images:              500
#
#  Model Comparison (Overall):
# --------------------------------------------------
#    vit_b_16                  78.00%
#    ENSEMBLE                  78.00% *
#
# ============================================================
# Inference Complete!
# ============================================================
#
#
# --------------------------------------------------------------------------------
# Evaluating: pixelate - Severity Level 5
# --------------------------------------------------------------------------------
# Overall Accuracy best_vit_b_16.pth: 74.60%
#
# ============================================================
# Ensemble Inference for ImageNetSubset
# ============================================================
#
# Device: CUDA (Tesla T4)
#
#  Loading 1 model(s):
#    ✓ vit_b_16             (val acc: 91.6%) from best_vit_b_16.pth
#
# ============================================================
#  Ensemble Evaluation on Direct Set
# ============================================================
#
#  Per-Class Accuracy Comparison:
#    Class                | Ensemble | vit_b_16
# -------------------------------------------------
#    binder               |    98.0% |        98.0% |
#    coffee_mug           |    66.0% |        66.0% |
#    computer_keyboard    |    86.0% |        86.0% |
#    mouse                |    36.0% |        36.0% |
#    notebook             |    58.0% |        58.0% |
#    remote_control       |    66.0% |        66.0% |
#    soup_bowl            |    96.0% |        96.0% |
#    teapot               |    96.0% |        96.0% |
#    toilet_tissue        |    72.0% |        72.0% |
#    wooden_spoon         |    72.0% |        72.0% |
# -------------------------------------------------
#
#  Performance Metrics:
# --------------------------------------------------
#    Overall Ensemble Accuracy: 74.60%
#    Oracle Accuracy:           74.60% (theoretical max)
#    Expected Calibration Error: 0.1877
#    Average Disagreement:        nan
#    Average Agreement Ratio:   100.0%
#    Total Images:              500
#
#  Model Comparison (Overall):
# --------------------------------------------------
#    vit_b_16                  74.60%
#    ENSEMBLE                  74.60% *
#
# ============================================================
# Inference Complete!
# ============================================================
#
#
# ================================================================================
# Evaluation Check
# ================================================================================
#
# ================================================================================
# Final: Accuracy across Corruption Types and Severity Levels for best_vit_b_16.pth
# ================================================================================
# Corruption  gaussian_noise  pixelate
# Severity
# 1                     85.8      87.6
# 2                     81.8      86.4
# 3                     80.4      84.0
# 4                     73.0      78.0
# 5                     64.2      74.6
#
# Save: best_vit_b_16.pth_corruption_evaluation_results.csv
# ✓ Plot saved to: best_vit_b_16.pth_corruption_evaluation_plot.png
# ✓ Results copied to Google Drive

# %% [markdown]
# ## Optional: Speichern der Ergebnisse auf Google Drive

# %%
# Kopieren Sie die Ergebnisse zu Google Drive
# !cp corruption_evaluation_results.csv /content/drive/MyDrive/
# !cp corruption_evaluation_plot.png /content/drive/MyDrive/

print("✓ Results copied to Google Drive")
# Out:
# ✓ Results copied to Google Drive
